# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## The Earth System components and typical timescales
#
# Q1: Which spheres is the Earth system composed of and what do they include/contain?
#
# Q2: What are periodically occuring processes in the Earth system and what are their timescales? Think very short period to very long period and create a table.
#
# Q3: When was the little ice age and how did it manifest in the Earth system?
#
# Q4: Which major vulcanic eruptions occured during the historical period considered in CMIP6 and when?

# %% [markdown]
# ## IPCC Language
#
# Get familiar with the IPCC language and background (IPCC Introduction Chapter 1) and answer the following questions:\
# (You can read more here: [IPCC AR6 Glossary](https://www.ipcc.ch/report/ar6/wg1/downloads/report/IPCC_AR6_WGI_AnnexVII.pdf), [Eyring et al., (2016)](https://gmd.copernicus.org/articles/9/1937/2016/gmd-9-1937-2016.pdf).)
#
# Q1: What is the difference between weather and climate?
#
# Q2: What is a\
#     climate forcing
#     response
#     feedback
#     sensitivity
#     equilibrium?
#
# Q3: Which positive and negative climate feedbacks exist?
#
# Q3: What is CMIP and which CMIPs exist for IPCC AR6?
#
# Q4: What is a Shared Socioeconomic Pathways (SSP) scenario?
#
# Q5: Explain the CMIP6 DECK experiments, historical experiments and scenario experiments.

# %%
Answer

# %% [markdown]
# ## Reanalysis vs. Climate model
#
# Q1: What is a reanalysis? What are the most commonly used reanalysis products used in Europe? Norway?
#
# Q2: How do historical runs of climate models, such as CMIP6 models, differ from reanalysis?

# %% [markdown]
# ## CMIP data
#
# Get familiar with the attributes of the model output files and answer the following questions:
#
# Q1: Which tables exist? What do they contain?
#
# Q2: Which temporal and spatial resolutions exist amongst the CMIP6 outputs? What is the 'typical' ESM resolution (in degrees and km)?
#
# Q3: Which different grid-types exist in the model output? Find some examples.
#
# Q4: What is an ensemble member? How to read/decode the ensemble member name?

# %% [markdown]
# Answers:

# %% [markdown]
# ## Accessing and plotting CMIP data
#
# - Plot a (nice) global map of the average daily 2m air temperature ( = surface air temperature) on your birthday (in your birth year) of a model of your choice.
# - Do the same for your birthday this year.
# - Which conclusions can you draw from this? Argue and make suggestions.

# %%
# start with importing the necessary packages
# import

# %% [markdown]
# - What was the surface air temperature at the location you were born on your birthday? (Don't read this from the map but from the data file.)
# - Do you think this was the actual temperature in your precise location? Argue.

# %%
# use the .sel() function
