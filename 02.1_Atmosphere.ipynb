# %% [markdown]
# # Model lab – Atmosphere Exercise
#
# ## AR5 to AR6 difference: GMST→GSAT
#
# ## Q1: How different are surface temperature and surface air temperature in CMIP6 historical experiment?

# %%
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np

# for catalog
import intake
import intake_esm
import gcsfs

# %matplotlib inline

# %% [markdown]
# ### Find the right variables for analysis: GMST - global mean surface temperature; GSAT - global surface air temperature. Choose a model to analyse.
#
# <details>
#     <summary>Hint</summary>
# You can look it up <a href="https://clipc-services.ceda.ac.uk/dreq/index/var.html">here</a> or in <a href="https://github.com/PCMDI/cmip6-cmor-tables">CMOR-tables</a> or  <a href="https://clipc-services.ceda.ac.uk/dreq/mipVars.html">MPI-variables</a>
# </details>

# %% [markdown]
# tas,
# ts

# %% [markdown]
# ### Choose climatology period (1961-1990) and read the data

# %%
# use the catalog to find available models (source_id), time periods (time_range), variables

# load the catalog
cmip6_catalog_path = '/mnt/tacco-ns1004k/catalogs/merged_local.json'
cmip6_catalog = intake.open_esm_datastore(cmip6_catalog_path)

# filter the catalog for a model, e.g. 'CESM2', the variables ('ts' and 'tas'), and the needed time-period
cat_subset = cmip6_catalog.search(experiment_id = "historical", variable_id = "tas", source_id = "CESM2", time_range = "195001-199912")

# inspect the filtered catalog as a pandas dataframe table
cat_subset.df

# choose the newest version and an ensemble member of your choice
cat_subset = cmip6_catalog.search(experiment_id = "historical", variable_id = "tas", source_id = "CESM2", time_range = "195001-199912", version = 20190514)

# inspect the filtered catalog as a pandas dataframe table
cat_subset.df

# someone stored this double.. choose any in that case and get the path to work with the data!
path_CESM2_tas_1950to1999 = cat_subset.df.path[0]
path_CESM2_tas_1950to1999
# Out:
# '/mnt/tacco-ns1004k-cmip/NCAR/CESM2/historical/r11i1p1f1/Amon/tas/gn/v20190514/tas_Amon_CESM2_historical_r11i1p1f1_gn_195001-199912.nc'

# %%
# load the data and work with them from here on
CESM2_tas_1950to1999 = xr.open_dataset(path_CESM2_tas_1950to1999)
CESM2_tas_1950to1999
# Out:
# /opt/conda/envs/labs/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'tas' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# <xarray.Dataset> Size: 133MB
# Dimensions:    (time: 600, lat: 192, lon: 288, nbnd: 2)
# Coordinates:
#   * lat        (lat) float64 2kB -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon        (lon) float64 2kB 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * time       (time) object 5kB 1950-01-15 12:00:00 ... 1999-12-15 12:00:00
# Dimensions without coordinates: nbnd
# Data variables:
#     tas        (time, lat, lon) float32 133MB ...
#     time_bnds  (time, nbnd) object 10kB ...
#     lat_bnds   (lat, nbnd) float64 3kB ...
#     lon_bnds   (lon, nbnd) float64 5kB ...
# Attributes: (12/45)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
# ...

# %% [markdown]
# ### Calculate weighted mean
#
#
# <details>
#     <summary>Hint</summary>
# You can look it up in <a href="https://docs.xarray.dev/en/latest/examples/area_weighted_temperature.html">xarray docs f.e.</a>
# </details>

# %% [markdown]
# ### Plot timeseries of GSAT and GMST and difference between them, as well as the anomalies of GSAT and GMST

# %% [markdown]
# ### Show a spatial pattern of the difference between tas and ts

# %% [markdown]
# ### Q2: How does a different climatology affect the above temperature differences?
# Use the climatology periods 1986-2005 and 1995-2014.

# %%
# how to merge different datafiles into one: create a list of paths
path1 = #put pathname
path2 = #put pathname
files = [path1, path2]

# merge datasets:
files_merged = xr.open_mfdataset(files[0:1], combine = 'by_coords')

# %% [markdown]
# ### Extension: use more ensemble members, more models etc.
