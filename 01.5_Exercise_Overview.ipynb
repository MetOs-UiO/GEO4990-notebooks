# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## IPCC Language
#
# Get familiar with the IPCC language and background (IPCC Introduction Chapter 1) and answer the following questions:
#
# Q1: What is the difference between weather and climate?
#
# Q2: Which positive and negative climate feedbacks exist?
#
# Q3: Which model resolution is available in AR6?
#
# Q4: What is CMIP and which CMIPs exist for IPCC AR6?
#
# Q5: What is a Shared Socioeconomic Pathways (SSP) scenario?
#
# Q5: What is a climate forcing, response, feedback, sensitivity, equilibrium?
#
# Q6: Explain the CMIP6 DECK experiments, historical experiments and scenario experiments.
# You can read more here: [Eyring et al., (2016)](https://gmd.copernicus.org/articles/9/1937/2016/gmd-9-1937-2016.pdf)

# %% [markdown]
# Answers:

# %% [markdown]
# ## CMIP data
#
# Get familiar with the attributes of the model output files and answer the following questions:
#
# Q7: Which tables exist? What do they contain?
#
# Q8: Which temporal and spatial resolutions exist amongst the CMIP6 outputs? What is the 'typical' ESM resolution (in degrees and km)?
#
# Q9: Which different grid-types exist?
#
# Q10: What is an ensemble member? How can the ensemble member name be read and understood / how can it be decoded?

# %% [markdown]
# Answers:

# %% [markdown]
# ## Accessing and plotting CMIP data
#
# - Plot a (nice) global map of the average daily 2m air temperature ( = surface air temperature) on your birthday (in your birth year) of a model of your choice.
# - Do the same for your birthday this year.
# - Which conclusions can you draw from this? Argue and make suggestions.

# %%
# start with importing the necessary packages
# import

# %% [markdown]
# - What was the surface air temperature at the location you were born on your birthday? (Don't read this from the map but from the data file.)
# - Do you think this was th actual temperature in your precise location? Argue.

# %%
# use the .sel() function
